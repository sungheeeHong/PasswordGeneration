# %% [markdown]
# ## Codebook을 만들기 위한 함수 제작용 주피터 파일.
# ### 본 파일은 'CodebookModule.py'

# %%
# input: list with string elements
# output: numpy array

# %% [markdown]
# ### NLP 복습 - by nltk

# %% [markdown]
# 참고<br>
# https://datascienceschool.net/03%20machine%20learning/03.01.01%20NLTK%20%EC%9E%90%EC%97%B0%EC%96%B4%20%EC%B2%98%EB%A6%AC%20%ED%8C%A8%ED%82%A4%EC%A7%80.html

# %% [markdown]
# #### Import & Load Data

# %%
# Natural Language Toolkit
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from nltk) (8.1.4)
# Requirement already satisfied: joblib in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from nltk) (1.3.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python311\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
# 연구용 말뭉치 자료 다운로드, 그 중 책 자료. 
# quiet=True: 다운로드 과정에서 출력되는 로그 메세지 숨기기
nltk.download("book", quiet=True)
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
# corpus(말뭉치) 중 gutenberg(저작권이 말소된 문학작품)의 file IDs
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
# 그 중 Jane Austen의 Emma를 보면 다음과 같은 string의 형태이다. 
emma_raw = nltk.corpus.gutenberg.raw("austen-emma.txt")
print(emma_raw[:1302])
# Out:
# [Emma by Jane Austen 1816]
#
# VOLUME I
#
# CHAPTER I
#
#
# Emma Woodhouse, handsome, clever, and rich, with a comfortable home
# and happy disposition, seemed to unite some of the best blessings
# of existence; and had lived nearly twenty-one years in the world
# with very little to distress or vex her.
#
# She was the youngest of the two daughters of a most affectionate,
# indulgent father; and had, in consequence of her sister's marriage,
# been mistress of his house from a very early period.  Her mother
# had died too long ago for her to have more than an indistinct
# remembrance of her caresses; and her place had been supplied
# by an excellent woman as governess, who had fallen little short
# of a mother in affection.
#
# Sixteen years had Miss Taylor been in Mr. Woodhouse's family,
# less as a governess than a friend, very fond of both daughters,
# but particularly of Emma.  Between _them_ it was more the intimacy
# of sisters.  Even before Miss Taylor had ceased to hold the nominal
# office of governess, the mildness of her temper had hardly allowed
# her to impose any restraint; and the shadow of authority being
# now long passed away, they had been living together as friend and
# friend very mutually attached, and Emma doing just what she liked;
# highly esteeming Miss Taylor's judgment, but directed chiefly by
# her own.

# %% [markdown]
# #### Tokenize

# %%
# sentence 별로 나누기
from nltk.tokenize import sent_tokenize
print(sent_tokenize(emma_raw[:1000])[3])
# Out:
# Sixteen years had Miss Taylor been in Mr. Woodhouse's family,
# less as a governess than a friend, very fond of both daughters,
# but particularly of Emma.

# %%
# word 단위로 나누기
from nltk.tokenize import word_tokenize
word_tokenize(emma_raw[50:100])
# Out:
# ['Emma',
#  'Woodhouse',
#  ',',
#  'handsome',
#  ',',
#  'clever',
#  ',',
#  'and',
#  'rich',
#  ',',
#  'with',
#  'a']

# %%
# RegexpTokenizer: 정규표현식(Regular expression)을 이용해 tokenize
from nltk.tokenize import RegexpTokenizer
# \w(alphabet, numbers) 패턴을 사용해 tokenize
retokenize = RegexpTokenizer("[\w]+")
emma_ret = retokenize.tokenize(emma_raw)

# %% [markdown]
# #### Morpheme(형태소) 분석

# %%
# Stemming: 변화된 단어의 접미사, 어미 제거 -> 형태소의 기본형 복구를 도움(정확히 기본형이 되는건 아님)
from nltk.stem import PorterStemmer, LancasterStemmer

# PorterStemmer, LancasterStemmer라는 두 가지 Stemming 알고리즘이 있음. 
# PorterStemmer: 접두사, 접미사를 제거해 더 일반적인 단어의 어간 생성. 단어의 원형에 더 가까우나 시간이 조금 더 오래 걸림
st1 = PorterStemmer()
# LancasterStemmer: 접두사, 접미사를 더 많이 제거해 짧은 어간을 생성. 시간은 조금 덜 걸림. 
st2 = LancasterStemmer()

words = ["fly", "flies", "flying", "flew", "flown"]

# words에 있는 각각의 words를 st1(Porter algorithm), st2(Lancaster algorithm)으로 stemming
print("Porter Stemmer   :", [st1.stem(w) for w in words])
print("Lancaster Stemmer    :", [st2.stem(w) for w in words])

emma_morph = [st1.stem(w) for w in emma_ret]
# Out:
# Porter Stemmer   : ['fli', 'fli', 'fli', 'flew', 'flown']
# Lancaster Stemmer    : ['fly', 'fli', 'fly', 'flew', 'flown']

# %%
# Lemmatizing: 같은 의미를 가지는 여러 단어를 사전형으로 통일하는 작업. 품사(POS, Part of speech)를 지정하는 경우 더 정확한 원형을 찾을 수 있다. 
# WordNetLemmatizer: WordNet 데이터베이스를 기반으로 Lemmatize
from nltk.stem import WordNetLemmatizer

lm = WordNetLemmatizer()

# words의 원소 w들 중 pos="v"(동사)인 단어에 대해 동사 원형을 추출한다. 
[lm.lemmatize(w, pos="v") for w in words]

emma_tokens = [lm.lemmatize(w) for w in emma_morph]

# %% [markdown]
# #### 품사 부착
# NLTK에서는 'Penn Treebank Tagset'을 사용해 품사를 부착한다. <br>
# - NNP: 단수 고유명사
# - VB: 동사
# - VBP: 동사 현재형
# - TO: to 전치사
# - NN: 명사(단수형 혹은 집합형)
# - DT: 관형사
# ...

# %%
# pos_tag: (단어 토큰, 품사)의 튜플 출력
from nltk.tag import pos_tag
sentence = "Emma refused to permit us to obtain the refuse permit"
tagged_list = pos_tag(word_tokenize(sentence))
tagged_list
# Out:
# [('Emma', 'NNP'),
#  ('refused', 'VBD'),
#  ('to', 'TO'),
#  ('permit', 'VB'),
#  ('us', 'PRP'),
#  ('to', 'TO'),
#  ('obtain', 'VB'),
#  ('the', 'DT'),
#  ('refuse', 'NN'),
#  ('permit', 'NN')]

# %%
# untag: 품사가 tagging된 튜플 제거
from nltk.tag import untag
untag(tagged_list)
# Out:
# ['Emma',
#  'refused',
#  'to',
#  'permit',
#  'us',
#  'to',
#  'obtain',
#  'the',
#  'refuse',
#  'permit']

# %%
# 같은 단어더라도 품사가 다르면 다른 토큰으로 처리해야 할 때(ex. Scikit-Learn)
def tokenizer(doc):
    # 튜플의 원소 사이에 "/" 를 넣어 합친다. 
    return ["/".join(p) for p in tagged_list]

tokenizer(sentence)
# Out:
# ['Emma/NNP',
#  'refused/VBD',
#  'to/TO',
#  'permit/VB',
#  'us/PRP',
#  'to/TO',
#  'obtain/VB',
#  'the/DT',
#  'refuse/NN',
#  'permit/NN']

# %% [markdown]
# #### Data Loading

# %%
token_data = emma_tokens
token_data
# Out:
# ['emma',
#  'by',
#  'jane',
#  'austen',
#  '1816',
#  'volum',
#  'i',
#  'chapter',
#  'i',
#  'emma',
#  'woodhous',
#  'handsom',
#  'clever',
#  'and',
#  'rich',
#  'with',
#  'a',
#  'comfort',
#  'home',
#  'and',
#  'happi',
#  'disposit',
#  'seem',
#  'to',
#  'unit',
#  'some',
#  'of',
#  'the',
#  'best',
#  'bless',
#  'of',
#  'exist',
#  'and',
#  'had',
#  'live',
#  'nearli',
#  'twenti',
#  'one',
#  'year',
#  'in',
#  'the',
#  'world',
#  'with',
#  'veri',
#  'littl',
#  'to',
#  'distress',
#  'or',
#  'vex',
#  'her',
#  'she',
#  'wa',
#  'the',
#  'youngest',
#  'of',
#  'the',
#  'two',
#  'daughter',
#  'of',
#  'a',
#  'most',
#  'affection',
#  'indulg',
#  'father',
#  'and',
#  'had',
#  'in',
#  'consequ',
#  'of',
#  'her',
#  'sister',
#  's',
#  'marriag',
#  'been',
#  'mistress',
#  'of',
#  'hi',
#  'hous',
#  'from',
#  'a',
#  'veri',
#  'earli',
#  'period',
#  'her',
#  'mother',
#  'had',
#  'die',
#  'too',
#  'long',
#  'ago',
#  'for',
#  'her',
#  'to',
#  'have',
#  'more',
#  'than',
#  'an',
#  'indistinct',
#  'remembr',
#  'of',
#  'her',
#  'caress',
#  'and',
#  'her',
#  'place',
#  'had',
#  'been',
#  'suppli',
#  'by',
#  'an',
#  'excel',
#  'woman',
#  'a',
#  'gover',
#  'who',
#  'had',
#  'fallen',
#  'littl',
#  'short',
#  'of',
#  'a',
#  'mother',
#  'in',
#  'affect',
#  'sixteen',
#  'year',
#  'had',
#  'miss',
#  'taylor',
#  'been',
#  'in',
#  'mr',
#  'woodhous',
#  's',
#  'famili',
#  'le',
#  'a',
#  'a',
#  'gover',
#  'than',
#  'a',
#  'friend',
#  'veri',
#  'fond',
#  'of',
#  'both',
#  'daughter',
#  'but',
#  'particularli',
#  'of',
#  'emma',
#  'between',
#  '_them_',
#  'it',
#  'wa',
#  'more',
#  'the',
#  'intimaci',
#  'of',
#  'sister',
#  'even',
#  'befor',
#  'miss',
#  'taylor',
#  'had',
#  'ceas',
#  'to',
#  'hold',
#  'the',
#  'nomin',
#  'offic',
#  'of',
#  'gover',
#  'the',
#  'mild',
#  'of',
#  'her',
#  'temper',
#  'had',
#  'hardli',
#  'allow',
#  'her',
#  'to',
#  'impos',
#  'ani',
#  'restraint',
#  'and',
#  'the',
#  'shadow',
#  'of',
#  'author',
#  'be',
#  'now',
#  'long',
#  'pas',
#  'away',
#  'they',
#  'had',
#  'been',
#  'live',
#  'togeth',
#  'a',
#  'friend',
#  'and',
#  'friend',
#  'veri',
#  'mutual',
#  'attach',
#  'and',
#  'emma',
#  'do',
#  'just',
#  'what',
#  'she',
#  'like',
#  'highli',
#  'esteem',
#  'miss',
#  'taylor',
#  's',
#  'judgment',
#  'but',
#  'direct',
#  'chiefli',
#  'by',
#  'her',
#  'own',
#  'the',
#  'real',
#  'evil',
#  'inde',
#  'of',
#  'emma',
#  's',
#  'situat',
#  'were',
#  'the',
#  'power',
#  'of',
#  'have',
#  'rather',
#  'too',
#  'much',
#  'her',
#  'own',
#  'way',
#  'and',
#  'a',
#  'disposit',
#  'to',
#  'think',
#  'a',
#  'littl',
#  'too',
#  'well',
#  'of',
#  'herself',
#  'these',
#  'were',
#  'the',
#  'disadvantag',
#  'which',
#  'threaten',
#  'alloy',
#  'to',
#  'her',
#  'mani',
#  'enjoy',
#  'the',
#  'danger',
#  'howev',
#  'wa',
#  'at',
#  'present',
#  'so',
#  'unperceiv',
#  'that',
#  'they',
#  'did',
#  'not',
#  'by',
#  'ani',
#  'mean',
#  'rank',
#  'a',
#  'misfortun',
#  'with',
#  'her',
#  'sorrow',
#  'came',
#  'a',
#  'gentl',
#  'sorrow',
#  'but',
#  'not',
#  'at',
#  'all',
#  'in',
#  'the',
#  'shape',
#  'of',
#  'ani',
#  'disagre',
#  'conscious',
#  'miss',
#  'taylor',
#  'marri',
#  'it',
#  'wa',
#  'miss',
#  'taylor',
#  's',
#  'loss',
#  'which',
#  'first',
#  'brought',
#  'grief',
#  'it',
#  'wa',
#  'on',
#  'the',
#  'wed',
#  'day',
#  'of',
#  'thi',
#  'belov',
#  'friend',
#  'that',
#  'emma',
#  'first',
#  'sat',
#  'in',
#  'mourn',
#  'thought',
#  'of',
#  'ani',
#  'continu',
#  'the',
#  'wed',
#  'over',
#  'and',
#  'the',
#  'bride',
#  'peopl',
#  'gone',
#  'her',
#  'father',
#  'and',
#  'herself',
#  'were',
#  'left',
#  'to',
#  'dine',
#  'togeth',
#  'with',
#  'no',
#  'prospect',
#  'of',
#  'a',
#  'third',
#  'to',
#  'cheer',
#  'a',
#  'long',
#  'even',
#  'her',
#  'father',
#  'compos',
#  'himself',
#  'to',
#  'sleep',
#  'after',
#  'dinner',
#  'a',
#  'usual',
#  'and',
#  'she',
#  'had',
#  'then',
#  'onli',
#  'to',
#  'sit',
#  'and',
#  'think',
#  'of',
#  'what',
#  'she',
#  'had',
#  'lost',
#  'the',
#  'event',
#  'had',
#  'everi',
#  'promis',
#  'of',
#  'happi',
#  'for',
#  'her',
#  'friend',
#  'mr',
#  'weston',
#  'wa',
#  'a',
#  'man',
#  'of',
#  'unexception',
#  'charact',
#  'easi',
#  'fortun',
#  'suitabl',
#  'age',
#  'and',
#  'pleasant',
#  'manner',
#  'and',
#  'there',
#  'wa',
#  'some',
#  'satisfact',
#  'in',
#  'consid',
#  'with',
#  'what',
#  'self',
#  'deni',
#  'gener',
#  'friendship',
#  'she',
#  'had',
#  'alway',
#  'wish',
#  'and',
#  'promot',
#  'the',
#  'match',
#  'but',
#  'it',
#  'wa',
#  'a',
#  'black',
#  'morn',
#  's',
#  'work',
#  'for',
#  'her',
#  'the',
#  'want',
#  'of',
#  'miss',
#  'taylor',
#  'would',
#  'be',
#  'felt',
#  'everi',
#  'hour',
#  'of',
#  'everi',
#  'day',
#  'she',
#  'recal',
#  'her',
#  'past',
#  'kind',
#  'the',
#  'kind',
#  'the',
#  'affect',
#  'of',
#  'sixteen',
#  'year',
#  'how',
#  'she',
#  'had',
#  'taught',
#  'and',
#  'how',
#  'she',
#  'had',
#  'play',
#  'with',
#  'her',
#  'from',
#  'five',
#  'year',
#  'old',
#  'how',
#  'she',
#  'had',
#  'devot',
#  'all',
#  'her',
#  'power',
#  'to',
#  'attach',
#  'and',
#  'amus',
#  'her',
#  'in',
#  'health',
#  'and',
#  'how',
#  'nurs',
#  'her',
#  'through',
#  'the',
#  'variou',
#  'ill',
#  'of',
#  'childhood',
#  'a',
#  'larg',
#  'debt',
#  'of',
#  'gratitud',
#  'wa',
#  'owe',
#  'here',
#  'but',
#  'the',
#  'intercours',
#  'of',
#  'the',
#  'last',
#  'seven',
#  'year',
#  'the',
#  'equal',
#  'foot',
#  'and',
#  'perfect',
#  'unreserv',
#  'which',
#  'had',
#  'soon',
#  'follow',
#  'isabella',
#  's',
#  'marriag',
#  'on',
#  'their',
#  'be',
#  'left',
#  'to',
#  'each',
#  'other',
#  'wa',
#  'yet',
#  'a',
#  'dearer',
#  'tender',
#  'recollect',
#  'she',
#  'had',
#  'been',
#  'a',
#  'friend',
#  'and',
#  'companion',
#  'such',
#  'a',
#  'few',
#  'posse',
#  'intellig',
#  'well',
#  'inform',
#  'use',
#  'gentl',
#  'know',
#  'all',
#  'the',
#  'way',
#  'of',
#  'the',
#  'famili',
#  'interest',
#  'in',
#  'all',
#  'it',
#  'concern',
#  'and',
#  'peculiarli',
#  'interest',
#  'in',
#  'herself',
#  'in',
#  'everi',
#  'pleasur',
#  'everi',
#  'scheme',
#  'of',
#  'her',
#  'one',
#  'to',
#  'whom',
#  'she',
#  'could',
#  'speak',
#  'everi',
#  'thought',
#  'a',
#  'it',
#  'aros',
#  'and',
#  'who',
#  'had',
#  'such',
#  'an',
#  'affect',
#  'for',
#  'her',
#  'a',
#  'could',
#  'never',
#  'find',
#  'fault',
#  'how',
#  'wa',
#  'she',
#  'to',
#  'bear',
#  'the',
#  'chang',
#  'it',
#  'wa',
#  'true',
#  'that',
#  'her',
#  'friend',
#  'wa',
#  'go',
#  'onli',
#  'half',
#  'a',
#  'mile',
#  'from',
#  'them',
#  'but',
#  'emma',
#  'wa',
#  'awar',
#  'that',
#  'great',
#  'must',
#  'be',
#  'the',
#  'differ',
#  'between',
#  'a',
#  'mr',
#  'weston',
#  'onli',
#  'half',
#  'a',
#  'mile',
#  'from',
#  'them',
#  'and',
#  'a',
#  'miss',
#  'taylor',
#  'in',
#  'the',
#  'hous',
#  'and',
#  'with',
#  'all',
#  'her',
#  'advantag',
#  'natur',
#  'and',
#  'domest',
#  'she',
#  'wa',
#  'now',
#  'in',
#  'great',
#  'danger',
#  'of',
#  'suffer',
#  'from',
#  'intellectu',
#  'solitud',
#  'she',
#  'dearli',
#  'love',
#  'her',
#  'father',
#  'but',
#  'he',
#  'wa',
#  'no',
#  'companion',
#  'for',
#  'her',
#  'he',
#  'could',
#  'not',
#  'meet',
#  'her',
#  'in',
#  'convers',
#  'ration',
#  'or',
#  'play',
#  'the',
#  'evil',
#  'of',
#  'the',
#  'actual',
#  'dispar',
#  'in',
#  'their',
#  'age',
#  'and',
#  'mr',
#  'woodhous',
#  'had',
#  'not',
#  'marri',
#  'earli',
#  'wa',
#  'much',
#  'increas',
#  'by',
#  'hi',
#  'constitut',
#  'and',
#  'habit',
#  'for',
#  'have',
#  'been',
#  'a',
#  'valetudinarian',
#  'all',
#  'hi',
#  'life',
#  'without',
#  'activ',
#  'of',
#  'mind',
#  'or',
#  'bodi',
#  'he',
#  'wa',
#  'a',
#  'much',
#  'older',
#  'man',
#  'in',
#  'way',
#  'than',
#  'in',
#  'year',
#  'and',
#  'though',
#  'everywher',
#  'belov',
#  'for',
#  'the',
#  'friendli',
#  'of',
#  'hi',
#  'heart',
#  'and',
#  'hi',
#  'amiabl',
#  'temper',
#  'hi',
#  'talent',
#  'could',
#  'not',
#  'have',
#  'recommend',
#  'him',
#  'at',
#  'ani',
#  'time',
#  'her',
#  'sister',
#  'though',
#  'compar',
#  'but',
#  'littl',
#  'remov',
#  'by',
#  'matrimoni',
#  'be',
#  'settl',
#  'in',
#  'london',
#  'onli',
#  'sixteen',
#  'mile',
#  'off',
#  'wa',
#  'much',
#  'beyond',
#  'her',
#  'daili',
#  'reach',
#  'and',
#  'mani',
#  'a',
#  'long',
#  'octob',
#  'and',
#  'novemb',
#  'even',
#  'must',
#  'be',
#  'struggl',
#  'through',
#  'at',
#  'hartfield',
#  'befor',
#  'christma',
#  'brought',
#  'the',
#  'next',
#  'visit',
#  'from',
#  'isabella',
#  'and',
#  'her',
#  'husband',
#  'and',
#  'their',
#  'littl',
#  'child',
#  'to',
#  'fill',
#  'the',
#  'hous',
#  'and',
#  'give',
#  'her',
#  'pleasant',
#  'societi',
#  'again',
#  'highburi',
#  'the',
#  'larg',
#  'and',
#  'popul',
#  'villag',
#  'almost',
#  'amount',
#  'to',
#  'a',
#  'town',
#  'to',
#  'which',
#  'hartfield',
#  'in',
#  'spite',
#  'of',
#  'it',
#  'separ',
#  'lawn',
#  'and',
#  'shrubberi',
#  'and',
#  'name',
#  'did',
#  'realli',
#  'belong',
#  'afford',
#  'her',
#  'no',
#  'equal',
#  'the',
#  'woodhous',
#  'were',
#  'first',
#  'in',
#  'consequ',
#  'there',
#  'all',
#  'look',
#  'up',
#  'to',
#  'them',
#  'she',
#  'had',
#  'mani',
#  'acquaint',
#  'in',
#  'the',
#  'place',
#  'for',
#  'her',
#  'father',
#  'wa',
#  'univers',
#  'civil',
#  'but',
#  'not',
#  'one',
#  'among',
#  'them',
#  'who',
#  'could',
#  'be',
#  'accept',
#  'in',
#  'lieu',
#  'of',
#  'miss',
#  'taylor',
#  'for',
#  'even',
#  'half',
#  'a',
#  'day',
#  'it',
#  'wa',
#  'a',
#  'melancholi',
#  'chang',
#  'and',
#  'emma',
#  'could',
#  'not',
#  'but',
#  'sigh',
#  'over',
#  'it',
#  'and',
#  'wish',
#  'for',
#  'imposs',
#  'thing',
#  'till',
#  'her',
#  'father',
#  'awok',
#  'and',
#  'made',
#  'it',
#  'necessari',
#  'to',
#  'be',
#  'cheer',
#  'hi',
#  'spirit',
#  'requir',
#  'support',
#  'he',
#  'wa',
#  'a',
#  'nervou',
#  'man',
#  'easili',
#  'depress',
#  'fond',
#  'of',
#  'everi',
#  'bodi',
#  'that',
#  'he',
#  'wa',
#  'use',
#  'to',
#  'and',
#  'hate',
#  'to',
#  'part',
#  'with',
#  'them',
#  'hate',
#  'chang',
#  'of',
#  'everi',
#  'kind',
#  'matrimoni',
#  'a',
#  'the',
#  'origin',
#  'of',
#  'chang',
#  'wa',
#  'alway',
#  'disagre',
#  'and',
#  'he',
#  'wa',
#  'by',
#  'no',
#  'mean',
#  'yet',
#  'reconcil',
#  'to',
#  'hi',
#  'own',
#  'daughter',
#  's',
#  'marri',
#  'nor',
#  'could',
#  'ever',
#  ...]

# %% [markdown]
# ### 1. Horizontal Sliding

# %%
hor = {'hor1' : 'qwertyuiop', 'hor2' : 'asdfghjkl', 'hor3' : 'zxcvbnm'}
coded_data = []

# %%
ht = 'qwertyuiop'
ct = ''
endpoint = 7
startpoint = 3
tl = list(range(endpoint, startpoint-1, -1 if endpoint > startpoint else 1))
ct += ht[i for i in tl]
# Out:
#   Cell In[87], line 6
#     ct += ht[i for i in tl]
#                ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
a = [1,2,3]
b = [4,5,6]
ab = {a[i] : b[i] for i in range(len(a))}
ab
# Out:
# {1: 4, 2: 5, 3: 6}

# %%
token_data = ['arithmeticerror'] # artyuiuythmertyuicerrtyuioiuytr

for token in token_data:
    coded_temp = ''
    for a_index in range(len(token)):
        if a_index + 1 == len(token):
            coded_data.append(coded_temp + token[a_index])
            break
        # 1. 연속된 두 단어가 같은 horizontal line 상에 있는지 확인
        if (token[a_index] in hor['hor1']) & (token[a_index + 1] in hor['hor1']):
            # startpoint, endpoint에 각각의 인덱스 저장
            startpoint = hor['hor1'].index(token[a_index])
            endpoint = hor['hor1'].index(token[a_index + 1])
            if startpoint == endpoint:
                coded_temp += hor['hor1'][startpoint]
                continue
            for i in range(startpoint, endpoint, 1 if endpoint > startpoint else -1):
                coded_temp += hor['hor1'][i]
        elif (token[a_index] in hor['hor2']) & (token[a_index + 1] in hor['hor2']):
            # startpoint, endpoint에 각각의 인덱스 저장
            startpoint = hor['hor2'].index(token[a_index])
            endpoint = hor['hor2'].index(token[a_index + 1])
            if startpoint == endpoint:
                coded_temp += hor['hor1'][startpoint]
                continue
            for i in range(startpoint, endpoint, 1 if endpoint > startpoint else -1):
                coded_temp += hor['hor2'][i]
        elif (token[a_index] in hor['hor3']) & (token[a_index + 1] in hor['hor3']):
            # startpoint, endpoint에 각각의 인덱스 저장
            startpoint = hor['hor3'].index(token[a_index])
            endpoint = hor['hor3'].index(token[a_index + 1])
            if startpoint == endpoint:
                coded_temp += hor['hor1'][startpoint]
                continue
            for i in range(startpoint, endpoint, 1 if endpoint > startpoint else -1):
                coded_temp += hor['hor3'][i]
        else:
            coded_temp += token[a_index]

# 2-1. 없으면 그대로 저장

# 2-2. 있으면 사이에 sliding 추가

# %%
coded_data
# Out:
# ['aiuyttyuthmtriuyicroiuytrtyui',
#  'aiuyttyuthmtriuyicroiuytrtyui',
#  'aiuyttyuthmtriuyicroiuytrtyui',
#  'artyuiuythmertyuicertyuioiuyt',
#  'artyuiuythmertyuicertyuioiuyt',
#  'artyuiuythmertyuicertyuioiuyt',
#  'artyuiuythmertyuicertyuioiuytr',
#  'artyuiuythmertyuicertyuioiuytr',
#  'artyuiuythmertyuicerrtyuioiuytr']

# %%
print(coded_data[8] == 'artyuiuythmertyuicerrtyuioiuytr')
print(coded_data[8])
print('artyuiuythmertyuicerrtyuioiuytr')
# Out:
# True
# artyuiuythmertyuicerrtyuioiuytr
# artyuiuythmertyuicerrtyuioiuytr

# %%
# 함수화 하기
def Codebook_HorizontalSliding(vocab:list):
    hor = {'hor1' : 'qwertyuiop', 'hor2' : 'asdfghjkl', 'hor3' : 'zxcvbnm'}
    coded_data = []
    for token in vocab:
        coded_temp = ''
        for a_index in range(len(token)):
            # out of range 처리
            if a_index + 1 == len(token):
                coded_data.append(coded_temp + token[a_index])
                break
            # 1. 연속된 두 단어가 같은 horizontal line 상에 있는지 확인
            if (token[a_index] in hor['hor1']) & (token[a_index + 1] in hor['hor1']):
                # startpoint, endpoint에 각각의 인덱스 저장
                startpoint = hor['hor1'].index(token[a_index])
                endpoint = hor['hor1'].index(token[a_index + 1])
                # 예외처리: startpoint, endpoint가 같은 경우
                if startpoint == endpoint:
                    coded_temp += token[a_index]
                    continue
                for i in range(startpoint, endpoint, 1 if endpoint > startpoint else -1):
                    coded_temp += hor['hor1'][i]
            elif (token[a_index] in hor['hor2']) & (token[a_index + 1] in hor['hor2']):
                # startpoint, endpoint에 각각의 인덱스 저장
                startpoint = hor['hor2'].index(token[a_index])
                endpoint = hor['hor2'].index(token[a_index + 1])
                # 예외처리: startpoint, endpoint가 같은 경우
                if startpoint == endpoint:
                    coded_temp += token[a_index]
                    continue
                for i in range(startpoint, endpoint, 1 if endpoint > startpoint else -1):
                    coded_temp += hor['hor2'][i]
            elif (token[a_index] in hor['hor3']) & (token[a_index + 1] in hor['hor3']):
                # startpoint, endpoint에 각각의 인덱스 저장
                startpoint = hor['hor3'].index(token[a_index])
                endpoint = hor['hor3'].index(token[a_index + 1])
                # 예외처리: startpoint, endpoint가 같은 경우
                if startpoint == endpoint:
                    coded_temp += token[a_index]
                    continue
                for i in range(startpoint, endpoint, 1 if endpoint > startpoint else -1):
                    coded_temp += hor['hor3'][i]
            else:
                coded_temp += token[a_index]
    codebook = {vocab[i] : coded_data[i] for i in range(len(vocab))}
    return codebook

# %%
Codebook_HorizontalSliding(emma_tokens)
# Out:
# {'emma': 'emma',
#  'by': 'by',
#  'jane': 'jhgfdsane',
#  'austen': 'austren',
#  '1816': '1816',
#  'volum': 'volum',
#  'i': 'i',
#  'chapter': 'chgfdsapoiuytrer',
#  'woodhous': 'wertyuioodfghoius',
#  'handsom': 'hgfdsandsom',
#  'clever': 'clever',
#  'and': 'and',
#  'rich': 'rtyuich',
#  'with': 'wertyuiuyth',
#  'a': 'a',
#  'comfort': 'comfoiuytrt',
#  'home': 'home',
#  'happi': 'hgfdsappoi',
#  'disposit': 'disposiuyt',
#  'seem': 'seem',
#  'to': 'tyuio',
#  'unit': 'uniuyt',
#  'some': 'some',
#  'of': 'of',
#  'the': 'the',
#  'best': 'best',
#  'bless': 'bless',
#  'exist': 'exist',
#  'had': 'hgfdsasd',
#  'live': 'live',
#  'nearli': 'nearli',
#  'twenti': 'trewentyui',
#  'one': 'one',
#  'year': 'ytrear',
#  'in': 'in',
#  'world': 'wertyuioiuytrlkjhgfd',
#  'veri': 'vertyui',
#  'littl': 'liuyttl',
#  'distress': 'distress',
#  'or': 'oiuytr',
#  'vex': 'vex',
#  'her': 'her',
#  'she': 'sdfghe',
#  'wa': 'wa',
#  'youngest': 'yuioiungest',
#  'two': 'trewertyuio',
#  'daughter': 'dsaughtrer',
#  'most': 'most',
#  'affection': 'asdffectyuion',
#  'indulg': 'indulkjhg',
#  'father': 'fdsather',
#  'consequ': 'consewqwertyu',
#  'sister': 'sistrer',
#  's': 's',
#  'marriag': 'marrtyuiasdfg',
#  'been': 'been',
#  'mistress': 'mistress',
#  'hi': 'hi',
#  'hous': 'hoius',
#  'from': 'frtyuiom',
#  'earli': 'earli',
#  'period': 'poiuytrertyuiod',
#  'mother': 'moiuyther',
#  'die': 'diuytre',
#  'too': 'tyuioo',
#  'long': 'long',
#  'ago': 'asdfgo',
#  'for': 'foiuytr',
#  'have': 'hgfdsave',
#  'more': 'moiuytre',
#  'than': 'thgfdsan',
#  'an': 'an',
#  'indistinct': 'indistyuinbvct',
#  'remembr': 'rememnbr',
#  'caress': 'caress',
#  'place': 'plkjhgfdsace',
#  'suppli': 'suioppli',
#  'excel': 'excel',
#  'woman': 'wertyuioman',
#  'gover': 'gover',
#  'who': 'who',
#  'fallen': 'fdsasdfghjkllen',
#  'short': 'sdfghoiuytrt',
#  'affect': 'asdffect',
#  'sixteen': 'sixtreen',
#  'miss': 'miss',
#  'taylor': 'tayloiuytr',
#  'mr': 'mr',
#  'famili': 'fdsamili',
#  'le': 'le',
#  'friend': 'frtyuiuytrend',
#  'fond': 'fond',
#  'both': 'boiuyth',
#  'but': 'buyt',
#  'particularli': 'partyuiculkjhgfdsarli',
#  'between': 'bertreween',
#  '_them_': '_them_',
#  'it': 'iuyt',
#  'intimaci': 'intyuimaci',
#  'even': 'even',
#  'befor': 'befoiuytr',
#  'ceas': 'ceas',
#  'hold': 'holkjhgfd',
#  'nomin': 'nomin',
#  'offic': 'offic',
#  'mild': 'milkjhgfd',
#  'temper': 'trempoiuytrer',
#  'hardli': 'hgfdsardfghjkli',
#  'allow': 'asdfghjklloiuytrew',
#  'impos': 'impos',
#  'ani': 'ani',
#  'restraint': 'restraint',
#  'shadow': 'sdfghgfdsasdoiuytrew',
#  'author': 'auythoiuytr',
#  'be': 'be',
#  'now': 'noiuytrew',
#  'pas': 'pas',
#  'away': 'away',
#  'they': 'therty',
#  'togeth': 'tyuiogerth',
#  'mutual': 'muytyuasdfghjkl',
#  'attach': 'attach',
#  'do': 'do',
#  'just': 'just',
#  'what': 'whgfdsat',
#  'like': 'like',
#  'highli': 'highjkli',
#  'esteem': 'estreem',
#  'judgment': 'judfgment',
#  'direct': 'diuytrect',
#  'chiefli': 'chiuytrefghjkli',
#  'own': 'oiuytrewn',
#  'real': 'reasdfghjkl',
#  'evil': 'evil',
#  'inde': 'inde',
#  'situat': 'siuytyuat',
#  'were': 'were',
#  'power': 'poiuytrewer',
#  'rather': 'rather',
#  'much': 'much',
#  'way': 'way',
#  'think': 'think',
#  'well': 'well',
#  'herself': 'herselkjhgf',
#  'these': 'these',
#  'disadvantag': 'disasdvantasdfg',
#  'which': 'which',
#  'threaten': 'threatren',
#  'alloy': 'asdfghjklloiuy',
#  'mani': 'mani',
#  'enjoy': 'enjoiuy',
#  'danger': 'dsanger',
#  'howev': 'hoiuytrewev',
#  'at': 'at',
#  'present': 'poiuytresent',
#  'so': 'so',
#  'unperceiv': 'unpoiuytrercertyuiv',
#  'that': 'thgfdsat',
#  'did': 'did',
#  'not': 'noiuyt',
#  'mean': 'mean',
#  'rank': 'rank',
#  'misfortun': 'misdfoiuytrtyun',
#  'sorrow': 'soiuytrrtyuioiuytrew',
#  'came': 'came',
#  'gentl': 'gentl',
#  'all': 'asdfghjkll',
#  'shape': 'sdfghgfdsapoiuytre',
#  'disagre': 'disasdfgre',
#  'conscious': 'conscioius',
#  'marri': 'marrtyui',
#  'loss': 'loss',
#  'first': 'fiuytrst',
#  'brought': 'brtyuioiught',
#  'grief': 'grtyuiuytref',
#  'on': 'on',
#  'wed': 'wed',
#  'day': 'dsay',
#  'thi': 'thi',
#  'belov': 'belov',
#  'sat': 'sat',
#  'mourn': 'moiuytrn',
#  'thought': 'thoiught',
#  'continu': 'contyuinu',
#  'over': 'over',
#  'bride': 'brtyuide',
#  'peopl': 'poiuytrertyuiopl',
#  'gone': 'gone',
#  'left': 'left',
#  'dine': 'dine',
#  'no': 'no',
#  'prospect': 'poiuytrtyuiospoiuytrect',
#  'third': 'thiuytrd',
#  'cheer': 'cheer',
#  'compos': 'compos',
#  'himself': 'himselkjhgf',
#  'sleep': 'sdfghjkleertyuiop',
#  'after': 'asdftrer',
#  'dinner': 'dinner',
#  'usual': 'usuasdfghjkl',
#  'then': 'then',
#  'onli': 'onli',
#  'sit': 'siuyt',
#  'lost': 'lost',
#  'event': 'event',
#  'everi': 'evertyui',
#  'promis': 'poiuytrtyuiomis',
#  'weston': 'westyuion',
#  'man': 'man',
#  'unexception': 'unexcertyuiopoiuytyuion',
#  'charact': 'chgfdsaract',
#  'easi': 'easi',
#  'fortun': 'foiuytrtyun',
#  'suitabl': 'suiuytabl',
#  'age': 'asdfge',
#  'pleasant': 'pleasant',
#  'manner': 'manner',
#  'there': 'there',
#  'satisfact': 'satyuisdfdsact',
#  'consid': 'consid',
#  'self': 'selkjhgf',
#  'deni': 'deni',
#  'gener': 'gener',
#  'friendship': 'frtyuiuytrendsdfghiop',
#  'alway': 'asdfghjklway',
#  'wish': 'wertyuisdfgh',
#  'promot': 'poiuytrtyuiomoiuyt',
#  'match': 'match',
#  'black': 'blkjhgfdsack',
#  'morn': 'moiuytrn',
#  'work': 'wertyuioiuytrk',
#  'want': 'want',
#  'would': 'wertyuioiulkjhgfd',
#  'felt': 'felt',
#  'hour': 'hoiuytr',
#  'recal': 'recasdfghjkl',
#  'past': 'past',
#  'kind': 'kind',
#  'how': 'hoiuytrew',
#  'taught': 'taught',
#  'play': 'plkjhgfdsay',
#  'five': 'five',
#  'old': 'olkjhgfd',
#  'devot': 'devoiuyt',
#  'amus': 'amus',
#  'health': 'heasdfghjklth',
#  'nurs': 'nuytrs',
#  'through': 'thrtyuioiugh',
#  'variou': 'vartyuioiu',
#  'ill': 'ill',
#  'childhood': 'chilkjhgfdfghood',
#  'larg': 'lkjhgfdsarg',
#  'debt': 'debt',
#  'gratitud': 'gratyuiuytyud',
#  'owe': 'oiuytrewe',
#  'here': 'here',
#  'intercours': 'intrercoiuytrs',
#  'last': 'lkjhgfdsast',
#  'seven': 'seven',
#  'equal': 'ewqwertyuasdfghjkl',
#  'foot': 'fooiuyt',
#  'perfect': 'poiuytrerfect',
#  'unreserv': 'unreserv',
#  'soon': 'soon',
#  'follow': 'folloiuytrew',
#  'isabella': 'isabellkjhgfdsa',
#  'their': 'thertyuiuytr',
#  'each': 'each',
#  'other': 'oiuyther',
#  'yet': 'ytrert',
#  'dearer': 'dearer',
#  'tender': 'trender',
#  'recollect': 'recollect',
#  'companion': 'companion',
#  'such': 'such',
#  'few': 'few',
#  'posse': 'posse',
#  'intellig': 'intrellig',
#  'inform': 'infoiuytrm',
#  'use': 'use',
#  'know': 'knoiuytrew',
#  'interest': 'intrerest',
#  'concern': 'conbvcern',
#  'peculiarli': 'poiuytreculiarli',
#  'pleasur': 'pleasuytr',
#  'scheme': 'scheme',
#  'whom': 'whom',
#  'could': 'coiulkjhgfd',
#  'speak': 'spoiuytreasdfghjk',
#  'aros': 'artyuios',
#  'never': 'never',
#  'find': 'find',
#  'fault': 'fdsault',
#  'bear': 'bear',
#  'chang': 'chgfdsang',
#  'true': 'trtyuytre',
#  'go': 'go',
#  'half': 'hgfdsasdfghjklkjhgf',
#  'mile': 'mile',
#  'them': 'them',
#  'awar': 'awar',
#  'great': 'great',
#  'must': 'must',
#  'differ': 'differ',
#  'advantag': 'asdvantasdfg',
#  'natur': 'natyuytr',
#  'domest': 'domest',
#  'suffer': 'suffer',
#  'intellectu': 'intrellectyu',
#  'solitud': 'soliuytyud',
#  'dearli': 'dearli',
#  'love': 'love',
#  'he': 'he',
#  'meet': 'meert',
#  'convers': 'conbvers',
#  'ration': 'ratyuion',
#  'actual': 'actyuasdfghjkl',
#  'dispar': 'dispar',
#  'increas': 'inbvcreas',
#  'constitut': 'constyuiuytyuyt',
#  'habit': 'hgfdsabiuyt',
#  'valetudinarian': 'vasdfghjklertyudinartyuian',
#  'life': 'life',
#  'without': 'wertyuiuythoiuyt',
#  'activ': 'actyuiv',
#  'mind': 'mind',
#  'bodi': 'bodi',
#  'older': 'olkjhgfder',
#  'though': 'thoiugh',
#  'everywher': 'evertytrewher',
#  'friendli': 'frtyuiuytrendfghjkli',
#  'heart': 'heart',
#  'amiabl': 'amiabl',
#  'talent': 'tasdfghjklent',
#  'recommend': 'recommend',
#  'him': 'him',
#  'time': 'tyuime',
#  'compar': 'compar',
#  'remov': 'remov',
#  'matrimoni': 'matrtyuimoni',
#  'settl': 'serttl',
#  'london': 'london',
#  'off': 'off',
#  'beyond': 'bertyuiond',
#  'daili': 'dsaili',
#  'reach': 'reach',
#  'octob': 'octyuiob',
#  'novemb': 'novemnb',
#  'struggl': 'strtyugghjkl',
#  'hartfield': 'hgfdsartfiuytrelkjhgfd',
#  'christma': 'chrtyuistma',
#  'next': 'next',
#  'visit': 'visiuyt',
#  'husband': 'husband',
#  'child': 'chilkjhgfd',
#  'fill': 'fill',
#  'give': 'give',
#  'societi': 'sociuytrertyui',
#  'again': 'asdfgfdsain',
#  'highburi': 'highbuytrtyui',
#  'popul': 'popoiul',
#  'villag': 'villkjhgfdsasdfg',
#  'almost': 'asdfghjklmost',
#  'amount': 'amoiunt',
#  'town': 'tyuioiuytrewn',
#  'spite': 'spoiuytre',
#  'separ': 'sertyuiopar',
#  'lawn': 'lkjhgfdsawn',
#  'shrubberi': 'sdfghrtyubbertyui',
#  'name': 'name',
#  'realli': 'reasdfghjklli',
#  'belong': 'belong',
#  'afford': 'asdffoiuytrd',
#  'look': 'look',
#  'up': 'uiop',
#  'acquaint': 'acqwertyuaint',
#  'univers': 'univers',
#  'civil': 'civil',
#  'among': 'among',
#  'accept': 'accertyuiopoiuyt',
#  'lieu': 'liuytrertyu',
#  'melancholi': 'melkjhgfdsanbvcholi',
#  'sigh': 'sigh',
#  'imposs': 'imposs',
#  'thing': 'thing',
#  'till': 'tyuill',
#  'awok': 'awertyuiok',
#  'made': 'masde',
#  'necessari': 'necessartyui',
#  'spirit': 'spoiuytrtyuiuyt',
#  'requir': 'rewqwertyuiuytr',
#  'support': 'suioppoiuytrt',
#  'nervou': 'nervoiu',
#  'easili': 'easili',
#  'depress': 'dertyuiopoiuytress',
#  'hate': 'hgfdsatre',
#  'part': 'part',
#  'origin': 'oiuytrtyuigin',
#  'reconcil': 'reconbvcil',
#  'nor': 'noiuytr',
#  'ever': 'ever',
#  'compass': 'compass',
#  'entir': 'entyuiuytr',
#  'when': 'when',
#  'oblig': 'oblig',
#  'selfish': 'selkjhgfisdfgh',
#  'abl': 'abl',
#  'suppos': 'suioppos',
#  'feel': 'feel',
#  'dispos': 'dispos',
#  'done': 'done',
#  'sad': 'sasd',
#  'deal': 'deasdfghjkl',
#  'happier': 'hgfdsappoiuytrer',
#  'if': 'if',
#  'spent': 'spoiuytrent',
#  'rest': 'rest',
#  'smile': 'smile',
#  'chat': 'chgfdsat',
#  'keep': 'keertyuiop',
#  'tea': 'trea',
#  'say': 'say',
#  'exactli': 'exactli',
#  'said': 'said',
#  'poor': 'pooiuytr',
#  'piti': 'poiuytyui',
#  'is': 'is',
#  'cannot': 'cannoiuyt',
#  'agre': 'asdfgre',
#  'you': 'yuioiu',
#  'papa': 'papa',
#  'good': 'good',
#  'humour': 'humoiuytr',
#  'thoroughli': 'thoiuytrtyuioiughjkli',
#  'deserv': 'deserv',
#  'wife': 'wertyuife',
#  'u': 'u',
#  'my': 'my',
#  'odd': 'odd',
#  'might': 'might',
#  'where': 'where',
#  'three': 'three',
#  'dear': 'dear',
#  'often': 'oftren',
#  'we': 'we',
#  'shall': 'sdfghgfdsasdfghjkll',
#  'see': 'see',
#  'come': 'come',
#  '_we_': '_we_',
#  'begin': 'begin',
#  'pay': 'pay',
#  'am': 'am',
#  'get': 'gert',
#  'far': 'fdsar',
#  'randal': 'randsasdfghjkl',
#  'distanc': 'distanbvc',
#  'walk': 'wasdfghjklk',
#  'nobodi': 'nobodi',
#  'your': 'yuioiuytr',
#  'carriag': 'carrtyuiasdfg',
#  'sure': 'suytre',
#  'jame': 'jhgfdsame',
#  'will': 'wertyuill',
#  'put': 'poiuyt',
#  'hors': 'hoiuytrs',
#  'are': 'are',
#  'while': 'while',
#  'our': 'oiuytr',
#  'into': 'intyuio',
#  'stabl': 'stabl',
#  'alreadi': 'asdfghjklreasdi',
#  'talk': 'tasdfghjklk',
#  'night': 'night',
#  'may': 'may',
#  'becaus': 'becaus',
#  'housemaid': 'hoiusemaid',
#  'doubt': 'doiubt',
#  'whether': 'wherther',
#  'take': 'tasdfghjke',
#  'anywher': 'anytrewher',
#  'el': 'el',
#  'got': 'goiuyt',
#  'hannah': 'hgfdsannasdfgh',
#  'mention': 'mentyuion',
#  'glad': 'ghjklkjhgfdsasd',
#  'lucki': 'lucki',
#  'slight': 'sdfghjklight',
#  'upon': 'uiopon',
#  'account': 'accoiunt',
#  'make': 'masdfghjke',
#  'servant': 'servant',
#  'pretti': 'poiuytrerttyui',
#  'spoken': 'spoken',
#  'girl': 'giuytrl',
#  'opinion': 'opoinion',
#  'whenev': 'whenev',
#  'curtsey': 'cuytrtserty',
#  'ask': 'asdfghjk',
#  'me': 'me',
#  'needlework': 'needfghjklewertyuioiuytrk',
#  'observ': 'observ',
#  'turn': 'tyuytrn',
#  'lock': 'lock',
#  'door': 'dooiuytr',
#  'right': 'rtyuight',
#  'bang': 'bang',
#  'somebodi': 'somebodi',
#  'about': 'aboiuyt',
#  'goe': 'goiuytre',
#  'hear': 'hear',
#  'tell': 'trell',
#  'spare': 'spare',
#  'exert': 'exert',
#  'maintain': 'maintain',
#  'flow': 'fghjkloiuytrew',
#  'idea': 'idea',
#  'hope': 'hopoiuytre',
#  'help': 'help',
#  'backgammon': 'backjhgfdsammon',
#  'toler': 'tyuioler',
#  'attack': 'attack',
#  'regret': 'regrert',
#  'tabl': 'tabl',
#  'visitor': 'visiuytyuioiuytr',
#  'immedi': 'immedi',
#  'afterward': 'asdftrereward',
#  'unnecessari': 'unnecessartyui',
#  'knightley': 'knightlerty',
#  'sensibl': 'sensibl',
#  'eight': 'ertyuight',
#  'thirti': 'thiuytrtyui',
#  'intim': 'intyuim',
#  'connect': 'connect',
#  'elder': 'elkjhgfder',
#  'brother': 'brtyuioiuyther',
#  'frequent': 'frewqwertyuytrent',
#  'welcom': 'welcom',
#  'directli': 'diuytrectli',
#  'connexion': 'connexion',
#  'return': 'rertyuytrn',
#  'late': 'lkjhgfdsatre',
#  'absenc': 'absenbvc',
#  'brunswick': 'brtyunswertyuick',
#  'squar': 'sqwertyuar',
#  'circumst': 'ciuytrcumst',
#  'anim': 'anim',
#  'inquiri': 'inqwertyuiuytrtyui',
#  'answer': 'answer',
#  'satisfactorili': 'satyuisdfdsactyuioiuytrtyuili',
#  'grate': 'gratre',
#  'out': 'oiuyt',
#  'call': 'casdfghjkll',
#  'afraid': 'asdfraid',
#  'shock': 'sdfghock',
#  'sir': 'siuytr',
#  'beauti': 'beauytyui',
#  'moonlight': 'moonlight',
#  'draw': 'draw',
#  'back': 'back',
#  'fire': 'fiuytre',
#  'found': 'foiund',
#  'damp': 'dsamp',
#  'dirti': 'diuytrtyui',
#  'catch': 'catch',
#  'cold': 'colkjhgfd',
#  'shoe': 'sdfghoiuytre',
#  'speck': 'spoiuytreck',
#  'quit': 'qwertyuiuyt',
#  'surpris': 'suytrtyuiopoiuytrtyuis',
#  'vast': 'vast',
#  'rain': 'rain',
#  'dread': 'dreasd',
#  'hard': 'hgfdsard',
#  'breakfast': 'breasdfghjkjhgfdsast',
#  'bye': 'bytre',
#  'joy': 'joiuy',
#  'sort': 'soiuytrt',
#  'hurri': 'huytrrtyui',
#  'congratul': 'congratyul',
#  'went': 'went',
#  'behav': 'behgfdsav',
#  'cri': 'crtyui',
#  'ah': 'asdfgh',
#  'ti': 'tyui',
#  'busi': 'busi',
#  'plea': 'plea',
#  'possibl': 'possibl',
#  'regard': 'regfdsard',
#  'question': 'qwertyuytrestyuion',
#  'depend': 'dertyuiopoiuytrend',
#  'independ': 'indertyuiopoiuytrend',
#  'rate': 'ratre',
#  'better': 'berttrer',
#  'especi': 'espoiuytreci',
#  '_one_': '_one_',
#  'those': 'those',
#  'fanci': 'fdsanbvci',
#  'troublesom': 'trtyuioiublesom',
#  'creatur': 'creatyuytr',
#  'head': 'heasd',
#  'certainli': 'certainli',
#  'believ': 'beliuytrev',
#  'sometim': 'somertyuim',
#  'dearest': 'dearest',
#  '_you_': '_yuioiu_',
#  'horribl': 'hoiuytrrtyuibl',
#  'oh': 'oh',
#  'meant': 'meant',
#  'myself': 'myselkjhgf',
#  'joke': 'joke',
#  'anoth': 'anoiuyth',
#  'fact': 'fdsact',
#  'told': 'tyuiolkjhgfd',
#  'agreeabl': 'asdfgreeabl',
#  'knew': 'knew',
#  'suspect': 'suspoiuytrect',
#  'flatter': 'fghjklkjhgfdsattrer',
#  'reflect': 'refghjklect',
#  'ha': 'hgfdsa',
#  'person': 'poiuytrerson',
#  'chanc': 'chgfdsanbvc',
#  'gainer': 'gfdsainer',
#  'let': 'lert',
#  'charmingli': 'chgfdsarminghjkli',
#  'punctual': 'poiunbvctyuasdfghjkl',
#  'tear': 'trear',
#  'face': 'fdsace',
#  'seen': 'seen',
#  'apart': 'apart',
#  'sorri': 'soiuytrrtyui',
#  'lose': 'lose',
#  '_will_': '_wertyuill_',
#  'divid': 'divid',
#  'should': 'sdfghoiulkjhgfd',
#  'import': 'impoiuytrt',
#  'secur': 'secuytr',
#  'provis': 'poiuytrtyuiovis',
#  'therefor': 'therefoiuytr',
#  'pain': 'pain',
#  'happili': 'hgfdsappoili',
#  'forgotten': 'foiuytrgoiuyttren',
#  'matter': 'mattrer',
#  'consider': 'consider',
#  'four': 'foiuytr',
#  'prove': 'poiuytrtyuiove',
#  'shook': 'sdfghook',
#  'fondli': 'fondfghjkli',
#  'repli': 'rertyuiopli',
#  'foretel': 'foiuytrertrel',
#  'whatev': 'whgfdsatrev',
#  'pray': 'poiuytray',
#  'none': 'none',
#  'greatest': 'greatrest',
#  'success': 'success',
#  'widow': 'wertyuidoiuytrew',
#  'perfectli': 'poiuytrerfectli',
#  'constantli': 'constantli',
#  'occupi': 'occuiopoi',
#  'either': 'ertyuiuyther',
#  'wherev': 'wherev',
#  'need': 'need',
#  'spend': 'spoiuytrend',
#  'singl': 'singhjkl',
#  'alon': 'asdfghjklon',
#  'deathb': 'deathb',
#  'son': 'son',
#  'uncl': 'unbvcl',
#  'solemn': 'solemn',
#  'nonsens': 'nonsens',
#  'subject': 'subject',
#  'sinc': 'sinbvc',
#  'met': 'mert',
#  'broadway': 'brtyuioasdway',
#  'lane': 'lkjhgfdsane',
#  'began': 'begfdsan',
#  'drizzl': 'drtyuizzl',
#  'dart': 'dsart',
#  'gallantri': 'gfdsasdfghjkllkjhgfdsantrtyui',
#  'borrow': 'boiuytrrtyuioiuytrew',
#  'umbrella': 'umnbrellkjhgfdsa',
#  'farmer': 'fdsarmer',
#  'mitchel': 'miuytchel',
#  'plan': 'plkjhgfdsan',
#  'instanc': 'instanbvc',
#  'leav': 'leav',
#  'understand': 'understand',
#  'endeavour': 'endeavoiuytr',
#  'properli': 'poiuytrtyuiopoiuytrerli',
#  'delic': 'delic',
#  'bring': 'brtyuing',
#  'worthi': 'wertyuioiuytrthi',
#  'employ': 'emploiuy',
#  'young': 'yuioiung',
#  'ladi': 'lkjhgfdsasdi',
#  'imagin': 'imasdfgin',
#  'yourself': 'yuioiuytrselkjhgf',
#  'idl': 'idfghjkl',
#  'whi': 'whi',
#  'merit': 'mertyuiuyt',
#  'proud': 'poiuytrtyuioiud',
#  'guess': 'guytress',
#  '_that_': '_thgfdsat_',
#  'can': 'can',
#  'known': 'knoiuytrewn',
#  'triumph': 'trtyuiumph',
#  'mere': 'mere',
#  'luck': 'luck',
#  'word': 'wertyuioiuytrd',
#  'quarrel': 'qwertyuarrel',
#  'claim': 'clkjhgfdsaim',
#  'drawn': 'drawn',
#  'pictur': 'poictyuytr',
#  'someth': 'somerth',
#  'noth': 'noiuyth',
#  'given': 'given',
#  'encourag': 'enbvcoiuytrasdfg',
#  'smooth': 'smooiuyth',
#  'enough': 'enoiugh',
#  'comprehend': 'compoiuytrehend',
#  'straightforward': 'straightfoiuytreward',
#  'open': 'opoiuytren',
#  'unaffect': 'unasdffect',
#  'safe': 'sasdfe',
#  'manag': 'manasdfg',
#  'harm': 'hgfdsarm',
#  'interfer': 'intrerfer',
#  'rejoin': 'rejoin',
#  'silli': 'silli',
#  'break': 'breasdfghjk',
#  'circl': 'ciuytrcl',
#  'grievous': 'grtyuiuytrevoius',
#  'elton': 'eltyuion',
#  'whole': 'whole',
#  'fit': 'fiuyt',
#  'shame': 'sdfghgfdsame',
#  'longer': 'longer',
#  'join': 'join',
#  'hand': 'hgfdsand',
#  'same': 'same',
#  'servic': 'servic',
#  'shew': 'sdfghew',
#  'attent': 'attrent',
#  'dare': 'dsare',
#  'laugh': 'lkjhgfdsaugh',
#  'invit': 'inbviuyt',
#  'fish': 'fisdfgh',
#  'chicken': 'chicken',
#  'chuse': 'chuse',
#  'six': 'six',
#  'care': 'care',
#  'ii': 'ii',
#  'nativ': 'natyuiv',
#  'born': 'boiuytrn',
#  'respect': 'respoiuytrect',
#  'rise': 'rtyuise',
#  'gentil': 'gentyuil',
#  'properti': 'poiuytrtyuiopoiuytrertyui',
#  'receiv': 'recertyuiv',
#  'educ': 'educ',
#  'succeed': 'succeed',
#  'small': 'smasdfghjkll',
#  'becom': 'becom',
#  'indispos': 'indispos',
#  'pursuit': 'poiuytrsuiuyt',
#  'engag': 'engfdsasdfg',
#  'satisfi': 'satyuisdfi',
#  'social': 'sociasdfghjkl',
#  'enter': 'entrer',
#  'militia': 'miliuytyuia',
#  'counti': 'coiuntyui',
#  'embodi': 'emnbodi',
#  'captain': 'capoiuytain',
#  'favourit': 'fdsavoiuytrtyuiuyt',
#  'militari': 'miliuytartyui',
#  'introduc': 'intrtyuioduc',
#  'churchil': 'chuytrchil',
#  'yorkshir': 'yuioiuytrkjhgfdsdfghiuytr',
#  'fell': 'fell',
#  'surpriz': 'suytrtyuiopoiuytrtyuiz',
#  'except': 'excertyuiopoiuyt',
#  'full': 'full',
#  'pride': 'poiuytrtyuide',
#  'offend': 'offend',
#  'command': 'command',
#  'bore': 'boiuytre',
#  'proport': 'poiuytrtyuiopoiuytrt',
#  'estat': 'estat',
#  'dissuad': 'dissuasd',
#  'took': 'tyuiook',
#  'infinit': 'infiniuyt',
#  'mortif': 'moiuytrtyuif',
#  'threw': 'threw',
#  'due': 'duytre',
#  'decorum': 'decoiuytrtyum',
#  'unsuit': 'unsuiuyt',
#  'produc': 'poiuytrtyuioduc',
#  'ought': 'oiught',
#  'whose': 'whose',
#  'warm': 'warm',
#  'sweet': 'sweert',
#  'resolut': 'resoluyt',
#  'pursu': 'poiuytrsu',
#  'refrain': 'refrain',
#  'unreason': 'unreason',
#  'anger': 'anger',
#  'luxuri': 'luxuytrtyui',
#  'former': 'foiuytrmer',
#  'incom': 'inbvcom',
#  'still': 'styuill',
#  'comparison': 'compartyuison',
#  'enscomb': 'enscomnb',
#  'onc': 'onbvc',
#  'amaz': 'amaz',
#  'worst': 'wertyuioiuytrst',
#  'bargain': 'bargfdsain',
#  'poorer': 'pooiuytrer',
#  'expens': 'expoiuytrens',
#  'reliev': 'reliuytrev',
#  'boy': 'boiuy',
#  'addit': 'asddiuyt',
#  'soften': 'softren',
#  'linger': 'linger',
#  'reconcili': 'reconbvcili',
#  'kindr': 'kindr',
#  'offer': 'offer',
#  'charg': 'chgfdsarg',
#  'frank': 'frank',
#  'deceas': 'deceas',
#  'scrupl': 'scrtyuiopl',
#  'reluct': 'reluct',
#  'overcom': 'overcom',
#  'wealth': 'weasdfghjklth',
#  'seek': 'seek',
#  'improv': 'impoiuytrtyuiov',
#  'complet': 'complert',
#  'becam': 'becam',
#  'desir': 'desiuytr',
#  'trade': 'trasde',
#  'establish': 'establisdfgh',
#  'favour': 'fdsavoiuytr',
#  'leisur': 'lertyuisuytr',
#  'occup': 'occuiop',
#  'eighteen': 'ertyuightreen',
#  'realis': 'reasdfghjklis',
#  'compet': 'compoiuytrert',
#  'purchas': 'poiuytrchgfdsas',
#  'adjoin': 'asdfghjoin',
#  'portionless': 'poiuytrtyuionless',
#  'accord': 'accoiuytrd',
#  'begun': 'begun',
#  'influenc': 'infghjkluytrenbvc',
#  'tyrann': 'tytrann',
#  'youth': 'yuioiuyth',
#  'shaken': 'sdfghgfdsasdfghjken',
#  'determin': 'dertrermin',
#  'sale': 'sasdfghjkle',
#  'forward': 'foiuytreward',
#  'steadili': 'streasdili',
#  'object': 'object',
#  'view': 'viuytrew',
#  'accomplish': 'accomplisdfgh',
#  'bought': 'boiught',
#  'obtain': 'obtain',
#  'new': 'new',
#  'probabl': 'poiuytrtyuiobabl',
#  'greater': 'greatrer',
#  'unhappi': 'unhgfdsappoi',
#  'second': 'second',
#  'delight': 'delight',
#  'judg': 'judfg',
#  'truli': 'trtyuli',
#  'pleasantest': 'pleasantrest',
#  'proof': 'poiuytrtyuioof',
#  'choos': 'choos',
#  'chosen': 'chosen',
#  'excit': 'exciuyt',
#  'choic': 'choic',
#  'tacitli': 'taciuytli',
#  'heir': 'hertyuiuytr',
#  'avow': 'avoiuytrew',
#  'adopt': 'asdopoiuyt',
#  'assum': 'assum',
#  'unlik': 'unlik',
#  'assist': 'assist',
#  'apprehens': 'appoiuytrehens',
#  'aunt': 'aunt',
#  'caprici': 'capoiuytrtyuici',
#  'govern': 'govern',
#  'capric': 'capoiuytrtyuic',
#  'strong': 'strtyuiong',
#  'deservedli': 'deservedfghjkli',
#  'saw': 'saw',
#  'report': 'rertyuiopoiuytrt',
#  'fine': 'fine',
#  'suffici': 'suffici',
#  'common': 'common',
#  'boast': 'boast',
#  'curio': 'cuytrtyuio',
#  'prevail': 'poiuytrevail',
#  'compliment': 'compliment',
#  'achiev': 'achiuytrev',
#  'propos': 'poiuytrtyuiopos',
#  'proper': 'poiuytrtyuiopoiuytrer',
#  'dissenti': 'dissentyui',
#  'voic': 'voic',
#  'perri': 'poiuytrerrtyui',
#  'drank': 'drank',
#  'bate': 'batre',
#  'strengthen': 'strengthen',
#  'understood': 'understyuiood',
#  'written': 'wertyuiuyttren',
#  'occas': 'occas',
#  'includ': 'inbvclud',
#  'letter': 'lerttrer',
#  'heard': 'heard',
#  'prize': 'poiuytrtyuize',
#  'cours': 'coiuytrs',
#  'form': 'foiuytrm',
#  'irresist': 'iuytrresist',
#  'sen': 'sen',
#  'sourc': 'soiuytrc',
#  'express': 'expoiuytress',
#  'partial': 'partyuiasdfghjkl',
#  'cool': 'cool',
#  'ennui': 'ennui',
#  'feebl': 'feebl',
#  'energi': 'energi',
#  'difficulti': 'difficultyui',
#  'privat': 'poiuytrtyuivat',
#  'conveni': 'conbveni',
#  'solitari': 'soliuytartyui',
#  'femal': 'femasdfghjkl',
#  'approach': 'appoiuytrtyuioach',
#  'season': 'season',
#  'hindranc': 'hindranbvc',
#  'week': 'week',
#  'altogeth': 'asdfghjkltyuiogerth',
#  'moment': 'moment',
#  'appar': 'appar',
#  'taken': 'tasdfghjken',
#  'centr': 'centr',
#  'attend': 'attrend',
#  'stay': 'stay',
#  'recov': 'recov',
#  'likelihood': 'likelihood',
#  'allevi': 'asdfghjkllevi',
#  'neighbour': 'nertyuighboiuytr',
#  'cake': 'casdfghjke',
#  'eat': 'eat',
#  'stomach': 'styuiomach',
#  'unwholesom': 'unwholesom',
#  'unfit': 'unfiuyt',
#  'earnestli': 'earnestli',
#  'tri': 'trtyui',
#  'vain': 'vain',
#  'prevent': 'poiuytrevent',
#  'consult': 'consult',
#  'apothecari': 'apoiuythecartyui',
#  'gentlemanlik': 'gentlemanlik',
#  'appli': 'appli',
#  'acknowledg': 'acknoiuytrewledfg',
#  'against': 'asdfgfdsainst',
#  'bia': 'bia',
#  'inclin': 'inbvclin',
#  'perhap': 'poiuytrerhgfdsap',
#  'unless': 'unless',
#  'moder': 'moder',
#  'confirm': 'confiuytrm',
#  'newli': 'newli',
#  'pair': 'paiuytr',
#  'eaten': 'eatren',
#  'benevol': 'benevol',
#  'nerv': 'nerv',
#  'strang': 'strang',
#  'rumour': 'rtyumoiuytr',
#  'slice': 'sdfghjklice',
#  'iii': 'iii',
#  'caus': 'caus',
#  'resid': 'resid',
#  'measur': 'measuytr',
#  'horror': 'hoiuytrrtyuioiuytr',
#  'parti': 'partyui',
#  'term': 'trerm',
#  'parish': 'partyuisdfgh',
#  'donwel': 'donwel',
#  'abbey': 'abberty',
#  'seat': 'seat',
#  'unfrequ': 'unfrewqwertyu',
#  'persuas': 'poiuytrersuas',
#  'prefer': 'poiuytrefer',
#  'unequ': 'unewqwertyu',
#  'compani': 'compani',
#  'scarc': 'scarc',
#  'card': 'card',
#  'stand': 'stand',
#  'privileg': 'poiuytrtyuivileg',
#  'exchang': 'exchgfdsang',
#  'vacant': 'vacant',
#  'blank': 'blkjhgfdsank',
#  'eleg': 'eleg',
#  ...}

# %% [markdown]
# ### 2. 모음대체 - QWERTY...

# %% [markdown]
# ### 3. 모음대체 - ASDF...

# %% [markdown]
# ### 4. 모음대체 - User가 입력한 숫자

# %% [markdown]
# ### 5. 모음대체 - User가 입력한 키워드

# %% [markdown]
# ### 6. 모음대체 - User가 입력한 숫자, 키워드(Upper)
